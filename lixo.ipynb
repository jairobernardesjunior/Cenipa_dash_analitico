# %%
import pandas as pd

#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#import warnings
#warnings.simplefilter('ignore')

# %%
df_ocorrencias = pd.read_csv( 'dataset_analise/df_acidentes_analise_ocorr.csv' )

df_ocorrencias['ocorrencia_dia'] = pd.to_datetime(df_ocorrencias['ocorrencia_dia'])

# %%
df_ocorrencias = df_ocorrencias.dropna()

# %%
def replace_apply(lx):
    lx = lx.replace('.', '')
    return lx

# %%
df_ocorrencias['ocorrencia_latitude'] = \
        df_ocorrencias['ocorrencia_latitude'].apply(replace_apply)

# %%
df_ocorrencias.ocorrencia_latitude.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5857 entries, 9 to 9818
# Series name: ocorrencia_latitude
# Non-Null Count  Dtype
# --------------  -----
# 5857 non-null   object
# dtypes: object(1)
# memory usage: 91.5+ KB

# %%
df_ocorrencias.head(5)
# Out:
#    ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 9                  ACIDENTE        MOGI GUAÇU            SP          BRASIL
# 28                 ACIDENTE        GUIRATINGA            MT          BRASIL
# 29                 ACIDENTE          BOCAIÚVA            MG          BRASIL
# 33                 ACIDENTE          LONDRINA            PR          BRASIL
# 34                 ACIDENTE         CATANDUVA            SP          BRASIL
#
#    ocorrencia_aerodromo ocorrencia_dia             ocorrencia_hora  \
# 9                   ***     2007-01-07  2024-05-10 11:30:00.000000
# 28                  ***     2007-01-18  2024-05-10 21:00:00.000000
# 29                  ***     2007-01-18  2024-05-10 09:10:00.000000
# 33                  ***     2007-01-19  2024-05-10 12:30:00.000000
# 34                  ***     2007-01-20  2024-05-10 03:00:00.000000
#
#    investigacao_status  total_aeronaves_envolvidas ocorrencia_saida_pista  \
# ...
